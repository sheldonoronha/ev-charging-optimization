# %%
import pandas as pd
import folium

# %%
# pop_data_path = '../data/raw/canada-population.xlsb'

# pop_data = pd.read_excel(pop_data_path, engine='pyxlsb')
# pop_data.head(5)

# new_col = ["geo_name", "area_type", "province", "population", "area","density"]
# pop_data.columns = new_col

# pop_data["province"].unique()

# pop_data = pop_data[(pop_data["province"] == "Ont.") & (pop_data["area_type"] != "Province")].reset_index(drop=True)
# pop_data.head()

# %%
# Load the data from the CSV file
file_path = "../data/raw/canada_data.xlsx"
df = pd.read_excel(file_path, engine="openpyxl")
map = "../data/maps/ontario.geojson"

# %%
df.head(5)
# Out:
#          City Area Size Province  Population  Population Density      lat  \
# 0       Acton     Small       ON        9377              1196.4  43.6295
# 1  Alexandria     Small       ON        2906              1404.6  45.3168
# 2      Alfred     Small       ON        1086              1254.9  45.5500
# 3    Alliston     Small       ON       23253              1238.3  44.1500
# 4     Almonte     Small       ON        6098              1466.6  45.2270
#
#       long
# 0 -80.0353
# 1 -74.6329
# 2 -74.8833
# 3 -79.8667
# 4 -76.1941

# %%
# Create a map centered at an average location
m = folium.Map([50, -82], zoom_start=5)
folium.GeoJson(map).add_to(m)

# Add markers to the map
for idx, row in df.iterrows():
    folium.Marker(
        location=[row['lat'], row['long']],
        popup=f"{row['City']}: Population Density {row['Population Density']}"
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e236697512a9afdc6fd194ad79b9d28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e236697512a9afdc6fd194ad79b9d28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e236697512a9afdc6fd194ad79b9d28 = L.map(
#                 &quot;map_2e236697512a9afdc6fd194ad79b9d28&quot;,
#                 {
#                     center: [50.0, -82.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09af7ffbc2bc636efb1c6f0e86b764a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09af7ffbc2bc636efb1c6f0e86b764a6.addTo(map_2e236697512a9afdc6fd194ad79b9d28);
#
#
#
#         function geo_json_63c65f7e64937264bb80d039c705f649_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_63c65f7e64937264bb80d039c705f649 = L.geoJson(null, {
#                 onEachFeature: geo_json_63c65f7e64937264bb80d039c705f649_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_63c65f7e64937264bb80d039c705f649_add (data) {
#             geo_json_63c65f7e64937264bb80d039c705f649
#                 .addData(data);
#         }
#             geo_json_63c65f7e64937264bb80d039c705f649_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-95.153437, 49.645347, 0], [-95.104438, 49.649193, 0], [-95.111169, 49.614545, 0], [-95.045839, 49.636417, 0], [-94.997065, 49.635263, 0], [-94.974982, 49.623471, 0], [-95.001085, 49.586006, 0], [-94.994749, 49.573126, 0], [-94.940162, 49.557331, 0], [-94.877137, 49.568608, 0], [-94.835721, 49.609374, 0], [-94.788057, 49.614591, 0], [-94.783722, 49.636148, 0], [-94.80792, 49.648537, 0], [-94.872756, 49.653587, 0], [-94.850126, 49.685254, 0], [-94.809678, 49.709713, 0], [-94.783327, 49.70226, 0], [-94.696253, 49.714471, 0], [-94.662968, 49.700939, 0], [-94.652926, 49.653876, 0], [-94.590449, 49.655453, 0], [-94.559746, 49.666737, 0], [-94.555388, 49.696092, 0], [-94.569662, 49.7513, 0], [-94.523597, 49.761414, 0], [-94.541171, 49.786224, 0], [-94.570888, 49.791383, 0], [-94.570726, 49.826331, 0], [-94.596805, 49.839251, 0], [-94.586823, 49.86783, 0], [